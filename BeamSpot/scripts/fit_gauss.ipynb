# %%
import ROOT
import pandas as pd
# Out:
# Welcome to JupyROOT 6.26/10

# %%
df = pd.read_csv('test.csv', index_col=0)

# %%
df.columns
# Out:
# Index(['BeamSpotZ_x'], dtype='object')

# %%
beamspots = df.BeamSpotZ_x.to_numpy()
beamspot = ROOT.RooRealVar("Beamspot", "Beamspot", -5, 5, "cm")

# %%
data = ROOT.RooDataSet.from_numpy({"Beamspot": beamspots}, [beamspot])
# Out:
# [#0] WARNING:DataHandling -- RooDataSet.from_numpy() Ignored 1459 out-of-range events

# %%
x, s = getFittedValues(df)
# Out:
# [#0] WARNING:DataHandling -- RooDataSet.from_numpy() Ignored 1459 out-of-range events
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
#  **********
#  **   21 **SET PRINT           1
#  **********
#  **********
#  **   22 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 mean         0.00000e+00  1.00000e+00   -5.00000e+00  5.00000e+00
#      2 sigma        1.00000e-01  4.50000e-02    1.00000e-02  5.00000e+00
#  **********
#  **   23 **SET ERR         0.5
#  **********
#  **********
#  **   24 **SET PRINT           1
#  **********
#  **********
#  **   25 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   26 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.95, mean=mean=0, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0.0100679	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0.0100679,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.95, mean=mean=0.0100679, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=-0.0100679	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = -0.0100679,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=-0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=-0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=-0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=-0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=-0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=-0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=-0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=-0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=-0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=-0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=-0.0100679, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.95, mean=mean=-0.0100679, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0.100672	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0.100672,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0.100672, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=-0.100672	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = -0.100672,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=-0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=-0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=-0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=-0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=-0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=-0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=-0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=-0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=-0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=-0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.85, mean=mean=-0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.95, mean=mean=-0.100672, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0	sigma=0.100466
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0,sigma = 0.100466)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0, sigma=sigma=0.100466
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0, sigma=sigma=0.100466
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0, sigma=sigma=0.100466
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0, sigma=sigma=0.100466
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0, sigma=sigma=0.100466
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0, sigma=sigma=0.100466
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0, sigma=sigma=0.100466
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0, sigma=sigma=0.100466
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0, sigma=sigma=0.100466
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0, sigma=sigma=0.100466
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0, sigma=sigma=0.100466
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.95, mean=mean=0, sigma=sigma=0.100466
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0	sigma=0.0995349
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0,sigma = 0.0995349)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0, sigma=sigma=0.0995349
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0, sigma=sigma=0.0995349
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0, sigma=sigma=0.0995349
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0, sigma=sigma=0.0995349
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0, sigma=sigma=0.0995349
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0, sigma=sigma=0.0995349
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0, sigma=sigma=0.0995349
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0, sigma=sigma=0.0995349
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0, sigma=sigma=0.0995349
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0, sigma=sigma=0.0995349
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0, sigma=sigma=0.0995349
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0, sigma=sigma=0.0995349
#     ... (remaining 14 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0	sigma=0.104716
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0,sigma = 0.104716)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0, sigma=sigma=0.104716
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0, sigma=sigma=0.104716
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0, sigma=sigma=0.104716
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0, sigma=sigma=0.104716
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0, sigma=sigma=0.104716
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0, sigma=sigma=0.104716
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0, sigma=sigma=0.104716
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0, sigma=sigma=0.104716
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0, sigma=sigma=0.104716
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0, sigma=sigma=0.104716
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=4.05, mean=mean=0, sigma=sigma=0.104716
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=4.15, mean=mean=0, sigma=sigma=0.104716
#     ... (remaining 10 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0	sigma=0.0954023
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0,sigma = 0.0954023)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0, sigma=sigma=0.0954023
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0, sigma=sigma=0.0954023
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0, sigma=sigma=0.0954023
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0, sigma=sigma=0.0954023
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0, sigma=sigma=0.0954023
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0, sigma=sigma=0.0954023
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0, sigma=sigma=0.0954023
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0, sigma=sigma=0.0954023
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0, sigma=sigma=0.0954023
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0, sigma=sigma=0.0954023
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0, sigma=sigma=0.0954023
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0, sigma=sigma=0.0954023
#     ... (remaining 16 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0.100672	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0.100672,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0.100672, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0.100672, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0.105705	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0.105705,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0.105705, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0.105705, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0.105705, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0.105705, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0.105705, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0.105705, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0.105705, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0.105705, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0.105705, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0.105705, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0.105705, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0.105705, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0.105957	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0.105957,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0.105957, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0.105957, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0.105957, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0.105957, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0.105957, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0.105957, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0.105957, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0.105957, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0.105957, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0.105957, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0.105957, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0.105957, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0.105969	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0.105969,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0.105969, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0.105969, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0.105969, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0.105969, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0.105969, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0.105969, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0.105969, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0.105969, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0.105969, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0.105969, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0.105969, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0.105969, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0.10597	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0.10597,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0.10597, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0.10597	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0.10597,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0.10597, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0.10597	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0.10597,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0.10597, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0.10597	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0.10597,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0.10597, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0.10597	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0.10597,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0.10597, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0.10597	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0.10597,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0.10597, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0.10597	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0.10597,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0.10597, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0.10597, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=1	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 1,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=1, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-inf) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=-1	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = -1,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=-1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.95, mean=mean=-1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.05, mean=mean=-1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.15, mean=mean=-1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.25, mean=mean=-1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.35, mean=mean=-1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.45, mean=mean=-1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.55, mean=mean=-1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.65, mean=mean=-1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.75, mean=mean=-1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.85, mean=mean=-1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.95, mean=mean=-1, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (0) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0	sigma=0.0593803
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0,sigma = 0.0593803)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0, sigma=sigma=0.0593803
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0, sigma=sigma=0.0593803
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0, sigma=sigma=0.0593803
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0, sigma=sigma=0.0593803
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0, sigma=sigma=0.0593803
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0, sigma=sigma=0.0593803
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0, sigma=sigma=0.0593803
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0, sigma=sigma=0.0593803
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0, sigma=sigma=0.0593803
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0, sigma=sigma=0.0593803
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0, sigma=sigma=0.0593803
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=0, sigma=sigma=0.0593803
#     ... (remaining 44 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (0) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=1	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 1,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=1, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=1, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (0) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=1.04927	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 1.04927,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=1.04927, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=1.04927, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=1.04927, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=1.04927, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=1.04927, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=1.04927, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=1.04927, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=1.04927, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=1.04927, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=1.04927, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=1.04927, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=1.04927, sigma=sigma=0.1
#     ... (remaining 13 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (0) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=1.05173	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 1.05173,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=1.05173, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=1.05173, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=1.05173, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=1.05173, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=1.05173, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=1.05173, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=1.05173, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=1.05173, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=1.05173, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=1.05173, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=1.05173, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=1.05173, sigma=sigma=0.1
#     ... (remaining 13 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (0) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=1.05185	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 1.05185,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=1.05185, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=1.05185, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=1.05185, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=1.05185, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=1.05185, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=1.05185, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=1.05185, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=1.05185, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=1.05185, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=1.05185, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=1.05185, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=1.05185, sigma=sigma=0.1
#     ... (remaining 13 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (0) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=1.05186	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 1.05186,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=1.05186, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=1.05186, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=1.05186, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=1.05186, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=1.05186, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=1.05186, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=1.05186, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=1.05186, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=1.05186, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=1.05186, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=1.05186, sigma=sigma=0.1
# ...
#     ... (remaining 25 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (808581) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=-2.39713	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = -2.39713,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.55, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.65, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.75, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.85, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.95, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.05, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.15, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.25, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.35, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.45, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.55, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.65, mean=mean=-2.39713, sigma=sigma=0.1
#     ... (remaining 25 messages suppressed)
#
#  MINUIT WARNING IN HESSE
#  ============== Second derivative zero for parameter1
#   MNHESS FAILS AND WILL RETURN DIAGONAL MATRIX.
#  FCN=808581 FROM MIGRAD    STATUS=CONVERGED      63 CALLS          64 TOTAL
#                      EDM=0    STRATEGY= 1  ERROR MATRIX UNCERTAINTY 100.0 per cent
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean         0.00000e+00   1.96591e-03   0.00000e+00   0.00000e+00
#    2  sigma        1.00000e-01   2.61103e-07   0.00000e+00   0.00000e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   3.865e-06  0.000e+00
#   0.000e+00  6.817e-14
# ERR MATRIX APPROXIMATE
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.00000   1.000  0.000
#         2  0.00000   0.000  1.000
#  ERR MATRIX APPROXIMATE
#  **********
#  **   27 **HESSE        1000
#  **********
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (808581) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.95, mean=mean=0, sigma=sigma=0.1
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (808581) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=2.39713	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 2.39713,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=2.39713, sigma=sigma=0.1
#     ... (remaining 25 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (808581) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=-2.39713	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = -2.39713,sigma = 0.1)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.55, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.65, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.75, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.85, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.95, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.05, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.15, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.25, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.35, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.45, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.55, mean=mean=-2.39713, sigma=sigma=0.1
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.65, mean=mean=-2.39713, sigma=sigma=0.1
#     ... (remaining 25 messages suppressed)
#
#  MINUIT WARNING IN HESSE
#  ============== Second derivative zero for parameter1
#   MNHESS FAILS AND WILL RETURN DIAGONAL MATRIX.
#  FCN=808581 FROM HESSE     STATUS=FAILED          3 CALLS          67 TOTAL
#                      EDM=0    STRATEGY= 1  ERROR MATRIX UNCERTAINTY 100.0 per cent
#   EXT PARAMETER                APPROXIMATE     INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  mean        -2.39713e+00   2.39713e+00   0.00000e+00   0.00000e+00
#    2  sigma        1.00000e-01   2.61103e-07   0.00000e+00  -1.30139e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   3.865e-06  0.000e+00
#   0.000e+00  6.817e-14
# ERR MATRIX APPROXIMATE
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.00000   1.000  0.000
#         2  0.00000   0.000  1.000
#  ERR MATRIX APPROXIMATE
#  **********
#  **   28 **SET ERR         0.5
#  **********
#  **********
#  **   29 **SET PRINT           1
#  **********
#  **********
#  **   30 **HESSE        1000
#  **********
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (808581) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=0	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 0 +/- 2.39713,sigma = 0.1 +/- 2.61103e-07)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=0 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=0 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=0 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=0 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=0 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=0 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=0 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=0 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=0 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=0 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=0 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=3.95, mean=mean=0 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#     ... (remaining 12 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (808581) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=2.39713	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = 2.39713 +/- 2.39713,sigma = 0.1 +/- 2.61103e-07)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.95, mean=mean=2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.85, mean=mean=2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.75, mean=mean=2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.65, mean=mean=2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.55, mean=mean=2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.45, mean=mean=2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.35, mean=mean=2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.25, mean=mean=2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.15, mean=mean=2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-4.05, mean=mean=2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.95, mean=mean=2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=-3.85, mean=mean=2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#     ... (remaining 25 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (808581) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=-2.39713	sigma=0.1
# RooNLLVar::nll_gauss_data_hist[ paramSet=(mean,sigma) ]
#      function value is NAN @ paramSet=(mean = -2.39713 +/- 2.39713,sigma = 0.1 +/- 2.61103e-07)
# RooGaussian::gauss[ x=Beamspot mean=mean sigma=sigma ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.55, mean=mean=-2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.65, mean=mean=-2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.75, mean=mean=-2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.85, mean=mean=-2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=1.95, mean=mean=-2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.05, mean=mean=-2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.15, mean=mean=-2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.25, mean=mean=-2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.35, mean=mean=-2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.45, mean=mean=-2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.55, mean=mean=-2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#      getLogVal() top-level p.d.f evaluates to zero @ x=Beamspot=2.65, mean=mean=-2.39713 +/- 2.39713, sigma=sigma=0.1 +/- 2.61103e-07
#     ... (remaining 25 messages suppressed)
#
#  MINUIT WARNING IN HESSE
#  ============== Second derivative zero for parameter1
#   MNHESS FAILS AND WILL RETURN DIAGONAL MATRIX.
#  FCN=808581 FROM HESSE     STATUS=FAILED          3 CALLS          70 TOTAL
#                      EDM=0    STRATEGY= 1  ERROR MATRIX UNCERTAINTY 100.0 per cent
#   EXT PARAMETER                APPROXIMATE     INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  mean        -2.39713e+00   2.39713e+00   0.00000e+00   0.00000e+00
#    2  sigma        1.00000e-01   2.61103e-07   0.00000e+00  -1.30139e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   3.865e-06  0.000e+00
#   0.000e+00  6.817e-14
# ERR MATRIX APPROXIMATE
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.00000   1.000  0.000
#         2  0.00000   0.000  1.000
#  ERR MATRIX APPROXIMATE
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %%
x, s
# Out:
# (-2.397127693021015, 0.10000000000000009)

# %%
def getFittedValues(df):
    beamspots = df.BeamSpotZ_x.to_numpy()
    beamspot = ROOT.RooRealVar("Beamspot", "Beamspot", -5, 5, "cm")
    data = ROOT.RooDataSet.from_numpy({f"Beamspot": beamspots}, [beamspot])

    # mean, std = fitTripleGauss(beamspot, data)
    mean, std = fitBinnedGauss(beamspot, data)
    return mean, std

# %%
def fitBinnedGauss(beamspot: ROOT.RooRealVar, data: ROOT.RooDataSet):
    beamspot.setBins(100)
    data_hist = ROOT.RooDataHist("data_hist", "data_hist", ROOT.RooArgList(beamspot), data)

    mean = ROOT.RooRealVar("mean", "mean", 0, -5, 5)
    sigma = ROOT.RooRealVar("sigma", "Sigma", 0.1, 0.01, 5)
    gauss = ROOT.RooGaussian("gauss", "gauss", beamspot, mean, sigma)

    gauss.fitTo(data_hist, ROOT.RooFit.Save())

    frame = beamspot.frame()
    data_hist.plotOn(frame)
    gauss.plotOn(frame)

    canvas = ROOT.TCanvas("canvas", "canvas", 800, 600)
    frame.Draw()
    canvas.Draw()
    frame.Draw()

    return mean.getVal(), sigma.getVal()

# %%
def fitTripleGauss(beamspot: ROOT.RooRealVar, data: ROOT.RooDataSet):
    mean = ROOT.RooRealVar("mean", "mean", 0, -5, 5)
    sigma1 = ROOT.RooRealVar("sigma1", "Sigma1", 2, 0.1, 10)
    sigma2 = ROOT.RooRealVar("sigma2", "Sigma2", 2, 0.1, 10)
    sigma3 = ROOT.RooRealVar("sigma3", "Sigma3", 2, 0.1, 10)

    gauss1 = ROOT.RooGaussian("gauss1", "Gauss 1", beamspot, mean, sigma1)
    gauss2 = ROOT.RooGaussian("gauss2", "Gauss 2", beamspot, mean, sigma2)
    gauss3 = ROOT.RooGaussian("gauss3", "Gauss 3", beamspot, mean, sigma3)

    frac1 = ROOT.RooRealVar("frac1", "Fraction 1", 0.5, 0, 1)
    frac2 = ROOT.RooRealVar("frac2", "Fraction 2", 0.5, 0, 1)

    model = ROOT.RooAddPdf("model", "Model", ROOT.RooArgList(gauss1, gauss2, gauss3), ROOT.RooArgList(frac1, frac2))

    model.fitTo(data, ROOT.RooFit.Save())


    frame = beamspot.frame()
    data.plotOn(frame, ROOT.RooFit.Name('dataset'))
    model.plotOn(frame, ROOT.RooFit.Name('model'))
    model.plotOn(frame, ROOT.RooFit.Components("gauss1"), ROOT.RooFit.LineStyle(ROOT.kDashed))
    model.plotOn(frame, ROOT.RooFit.Components("gauss2"), ROOT.RooFit.LineStyle(ROOT.kDashed), ROOT.RooFit.LineColor(ROOT.kRed))
    model.plotOn(frame, ROOT.RooFit.Components("gauss3"), ROOT.RooFit.LineStyle(ROOT.kDashed), ROOT.RooFit.LineColor(ROOT.kGreen))

    chi2 = frame.chiSquare("model", "dataset", 6)

    model.paramOn(frame, ROOT.RooFit.Layout(0.6, 0.9, 0.9))
    frame.getAttText().SetTextSize(0.03)
    pt = frame.findObject("model_paramBox")
    pt.AddText(ROOT.Form(f"Chi2/ndof =  {chi2:.2f}"))

    # Canvas
    canvas = ROOT.TCanvas("canvas", "canvas", 800, 600)
    frame.Draw()
    canvas.Draw()

    return mean.getVal(), sigma1.getVal()
